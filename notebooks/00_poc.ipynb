# %% [markdown]
# # Concepts and to test the concepts

# %% [markdown]
# ### Ollama local model
# ![ollama.png](attachment:ollama.png)

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
load_dotenv()

# %%
ollama_base_url = 'http://localhost:11434/v1/'
ollama_api_key =  'ollama'  # required but ignored
ollama_model_name = 'gemma3:1b'
prompt= [{
            "role":"user",
            "content":"what is ollama? and what is gemma3?"
        }]

# %%
client = OpenAI(
    base_url=ollama_base_url,
    api_key=ollama_api_key,
)


response = client.responses.create(
    model=ollama_model_name,
    input=prompt
)


print(response.output[0].content[0].text)

# %% [markdown]
# ### Deepseek Model
# ![deepseek.png](attachment:deepseek.png)

# %%
deepseek_base_url = "https://api.deepseek.com"
deepseek_api_key = os.getenv("DEEPSEEK_API_KEY", "")
print(deepseek_api_key)
deepseek_model_name = "deepseek-chat"
prompt = [{
    "role": "user",
    "content": "what is DeepSeek? and what is its latest model?"
}]

# %%
client = OpenAI(
    base_url=deepseek_base_url,
    api_key=deepseek_api_key,
)


response = client.chat.completions.create(
    model=deepseek_model_name,
    messages=prompt,
    stream=False
)


print(response.choices[0].message.content)

# %% [markdown]
# ### GROQ Model
# ![groq.png](attachment:groq.png)

# %%
import os
deepseek_api_key = os.getenv("DEEPSEEK_API_KEY", "")
print(deepseek_api_key)

groq_api_key = os.getenv("GROQ_API_KEY", "SHIT_HAPPENS")
print(groq_api_key)

closed_other_api_key = os.getenv("CLOSEDAI_API_KEY", "SHIT_HAPPENS")
print(closed_other_api_key)

# %%
groq_base_url = "https://api.groq.com/openai/v1"
groq_api_key = os.getenv("GROQ_API_KEY", "")

print(groq_api_key)

groq_model_name = "openai/gpt-oss-120b"
prompt = [{
    "role": "user",
    "content": "what is Groq? and what is its latest model?"
}]

# %%
client = OpenAI(
    base_url=groq_base_url,
    api_key=groq_api_key,
)


response = client.responses.create(
    model=groq_model_name,
    input=prompt
)


print(response.output[0].content[0].text)

# %% [markdown]
# ### xGrok Model
# ![grok.png](attachment:grok.png)

# %%
grok_base_url = "https://api.x.ai/v1"
grok_api_key = os.getenv("GROK_API_KEY", "")

grok_model_name = "grok-4-latest"
prompt = [{
    "role": "user",
    "content": "what is Grok? and what is its latest model?"
}]

# %%
client = OpenAI(
    base_url=grok_base_url,
    api_key=grok_api_key,
)


response = client.responses.create(
    model=grok_model_name,
    input=prompt
)


print(response.output[0].content[0].text)

# %% [markdown]
# ### Mistral Model
# ![mistral.png](attachment:mistral.png)

# %%
mistral_base_url = "https://api.mistral.ai/v1"
mistral_api_key = os.getenv("MISTRAL_API_KEY", "")

print(mistral_api_key)

mistral_model_name = "mistral-small-latest"
prompt = [{
    "role": "user",
    "content": "what is Mistral? and what is its latest model?"
}]

# %%
client = OpenAI(
    base_url=mistral_base_url,
    api_key=mistral_api_key,
)


response = client.chat.completions.create(
    model=mistral_model_name,
    messages=prompt,
    stream=False,
)


print(response.choices[0].message.content)

# %% [markdown]
# ### Open AI
# ![gemini.png](attachment:gemini.png)

# %%
gemini_base_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
gemini_api_key = os.getenv("GOOGLE_API_KEY", "")
print(gemini_api_key)
gemini_model_name = "gemini-2.5-flash"
prompt = [{
    "role": "user",
    "content": "what is Gemini? and what is its latest model?"
}]

# %%
client = OpenAI(
    base_url=gemini_base_url,
    api_key=gemini_api_key,
)


response = client.chat.completions.create(
    model=gemini_model_name,
    messages=prompt,
    stream=False,
)

print(response.choices[0].message.content)

# %% [markdown]
# ### Open AI - ChatGPT
# ![openai.png](attachment:openai.png)

# %%
# emini_base_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
openai_api_key = os.getenv("OPENAI_API_KEY", "")
print(openai_api_key)
openai_model_name = "gpt-5-nano"
prompt = [{
    "role": "user",
    "content": "what is GPT-5.2? and what is its latest model?"
}]

# %%
client = OpenAI(
    api_key=openai_api_key,
)


response = client.responses.create(
    model=openai_model_name,
    input=prompt
)


print(response.output_text)

# %% [markdown]
# ### Anthropic Claude
# ![claude.png](attachment:claude.png)

# %%
claude_base_url = "https://api.anthropic.com/v1/"
claude_api_key = os.getenv("ANTHROPIC_API_KEY", "")
print(claude_api_key)
claude_model_name = "claude-haiku-4-5"
prompt = [{
    "role": "user",
    "content": "what is Claude? and what is its latest model?"
}]

# %%
client = OpenAI(
    base_url=claude_base_url,
    api_key=claude_api_key,
)


response = client.chat.completions.create(
    model=claude_model_name,
    messages=prompt,
    stream=False,
)


print(response.choices[0].message.content)
